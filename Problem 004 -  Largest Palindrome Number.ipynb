# %%
for x in range(100,999):
    for y in range(100,999):
        z = x * y
        z = str(z) 
        if len(z) > 5: 
            if z[5] == z[0] and z[4] == z[1] and z[3] == z[2]:
                print(z)
# Out:
# 106601
# 119911
# 117711
# 110011
# 105501
# 101101
# 111111
# 121121
# 131131
# 141141
# 108801
# 143341
# 102201
# 165561
# 155551
# 127721
# 133331
# 168861
# 174471
# 180081
# 142241
# 102201
# 137731
# 154451
# 171171
# 189981
# 204402
# 210012
# 188881
# 182281
# 108801
# 111111
# 138831
# 141141
# 168861
# 171171
# 198891
# 219912
# 222222
# 219912
# 128821
# 201102
# 214412
# 227722
# 171171
# 215512
# 105501
# 133331
# 161161
# 178871
# 221122
# 238832
# 210012
# 111111
# 222222
# 117711
# 213312
# 219912
# 234432
# 255552
# 239932
# 122221
# 244442
# 111111
# 141141
# 171171
# 222222
# 252252
# 220022
# 201102
# 270072
# 202202
# 212212
# 222222
# 232232
# 242242
# 252252
# 262262
# 272272
# 282282
# 198891
# 239932
# 234432
# 219912
# 252252
# 234432
# 161161
# 168861
# 123321
# 156651
# 189981
# 213312
# 246642
# 279972
# 225522
# 256652
# 212212
# 219912
# 232232
# 239932
# 252252
# 259952
# 272272
# 279972
# 292292
# 299992
# 231132
# 174471
# 286682
# 215512
# 149941
# ...

# %%
t = 0 
t= str(t)
for x in range(100,999):
    for y in range(100,999):
        z = x * y
        z = str(z)
        if len(z) > 5:
            if z[5] == z[0] and z[4] == z[1] and z[3] == z[2]:
                if t<=z:
                    t=z
print(t)
# Out:
# 906609
